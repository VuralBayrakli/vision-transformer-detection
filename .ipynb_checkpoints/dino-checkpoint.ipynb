# %% [markdown]
# # Notes
#
# We provide this notebook for inference and visualizations.
#
# You can either load images from a dataloader(see Sec. 1) or from a local path(see Sec. 2).
#
# Welcome to join [IDEA](https://idea.edu.cn/en)([中文网址](https://idea.edu.cn/))!

# %%
import sys
sys.path.append("/content/drive/MyDrive/colab/DINO")

# %%
# !pip install addict

# %%
# !pip install yapf==0.40.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 4.2 MB/s eta 0:00:00
# ...

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.5 MB/s eta 0:00:00
# ...

# %%
# !python /content/drive/MyDrive/colab/DINO/models/dino/ops/setup.py build install

# %%
import os, sys
import torch, json
import numpy as np

from main import build_model_main
from util.slconfig import SLConfig
from datasets import build_dataset
from util.visualizer import COCOVisualizer
from util import box_ops

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 0. Initialize and Load Pre-trained Models

# %%
model_config_path = "/content/drive/MyDrive/colab/DINO/config/DINO/DINO_4scale.py" # change the path of the model config file
model_checkpoint_path = "/content/drive/MyDrive/colab/DINO/logs/DINO/R50-MS7/checkpoint0023.pth" # change the path of the model checkpoint
# See our Model Zoo section in README.md for more details about our pretrained models.

# %%
# !python /content/drive/MyDrive/colab/DINO/main.py \
	--output_dir /content/drive/MyDrive/colab/DINO/logs/DINO/R50-MS7 -c /content/drive/MyDrive/colab/DINO/config/DINO/DINO_4scale.py --coco_path "/content/drive/MyDrive/colab/firedino" \
	--options dn_scalar=100 embed_init_tgt=TRUE \
	dn_label_coef=1.0 dn_bbox_coef=1.0 use_ema=False \
	dn_box_noise_scale=1.0
# Out:
# Not using distributed mode
# Loading config file from /content/drive/MyDrive/colab/DINO/config/DINO/DINO_4scale.py
# [01/09 10:47:18.668]: git:
#   sha: 69f0d5e3c8d8cbb6c0f4ed7bc1f518a8bfb8f8b2, status: has uncommited changes, branch: main
#
# [01/09 10:47:19.052]: Command: /content/drive/MyDrive/colab/DINO/main.py --output_dir /content/drive/MyDrive/colab/DINO/logs/DINO/R50-MS7 -c /content/drive/MyDrive/colab/DINO/config/DINO/DINO_4scale.py --coco_path /content/drive/MyDrive/colab/firedino --options dn_scalar=100 embed_init_tgt=TRUE dn_label_coef=1.0 dn_bbox_coef=1.0 use_ema=False dn_box_noise_scale=1.0
# [01/09 10:47:19.362]: Full config saved to /content/drive/MyDrive/colab/DINO/logs/DINO/R50-MS7/config_args_all.json
# [01/09 10:47:19.363]: world size: 1
# [01/09 10:47:19.363]: rank: 0
# [01/09 10:47:19.363]: local_rank: 0
# ...

# %%
args = SLConfig.fromfile(model_config_path)
args.device = 'cuda'
model, criterion, postprocessors = build_model_main(args)
checkpoint = torch.load(model_checkpoint_path, map_location='cpu')
model.load_state_dict(checkpoint['model'])
_ = model.eval()

# %% [markdown]
# ## 1.3 Visualize Model Predictions

# %%
output = model.cuda()(image[None].cuda())
output = postprocessors['bbox'](output, torch.Tensor([[1.0, 1.0]]).cuda())[0]

# %%
thershold = 0.3 # set a thershold

scores = output['scores']
labels = output['labels']
boxes = box_ops.box_xyxy_to_cxcywh(output['boxes'])
select_mask = scores > thershold

# %%
box_label = [id2name[int(item)] for item in labels[select_mask]]
pred_dict = {
    'boxes': boxes[select_mask],
    'size': targets['size'],
    'box_label': box_label
}
vslzr.visualize(image, pred_dict, savedir=None)

# %% [markdown]
# # 2. Visualize Custom Images

# %%
from PIL import Image
import datasets.transforms as T

# %%
image = Image.open("/content/drive/MyDrive/colab/firedino/test/fire-7141-77747214_png_jpg.rf.b79a61e9ebfdf72ee643d2c49d94f681.jpg").convert("RGB") # load image

# %%
# transform images
transform = T.Compose([
    T.RandomResize([800], max_size=1333),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
image, _ = transform(image, None)

# %%
# predict images
output = model.cuda()(image[None].cuda())
output = postprocessors['bbox'](output, torch.Tensor([[1.0, 1.0]]).cuda())[0]

# %%
# visualize outputs
thershold = 0.27 # set a thershold

vslzr = COCOVisualizer()

scores = output['scores']
labels = output['labels']
boxes = box_ops.box_xyxy_to_cxcywh(output['boxes'])
select_mask = scores > thershold

#box_label = [id2name[int(item)] for item in labels[select_mask]]
#box_label = ["aero_plane"]
box_label = ["fire" for i in range(len(boxes[select_mask]))]
pred_dict = {
    'image_idd': 4,
    'boxes': boxes[select_mask],
    'size': torch.Tensor([image.shape[1], image.shape[2]]),
    'box_label': box_label
}
vslzr.visualize(image, pred_dict, savedir=None, dpi=200)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
import torchvision.transforms as transforms
from PIL import Image
import torchvision.transforms as T

# Transformasyonları tanımlayın
transform2 = T.Compose([
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


video_path = "/content/drive/MyDrive/colab/istockphoto-1413851357-640_adpp_is.mp4"  # Video dosya adını ve yolunu belirtin
cap = cv2.VideoCapture(video_path)
sayac = 0
while cap.isOpened():
    ret, frame = cap.read()
    image_path = f"/content/drive/MyDrive/colab/firedino/frame_{sayac}{cap.get(cv2.CAP_PROP_POS_FRAMES)}.jpg"  # İmage dosya adını ve yolunu belirtin

    # OpenCV görüntüsünü image olarak kaydet
    cv2.imwrite(image_path, frame)

    image = Image.open("/content/drive/MyDrive/colab/firedino/frame.jpg").convert("RGB") # load image
    if not ret:
        break
    # İmage dosya adını ve yolunu belirtin
    # Her kareyi tensora dönüştürün ve normalize edin
        #cv2_imshow(frame)
    if cv2.waitKey(25) & 0xFF == ord("q"):
        break
    sayac += 1

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-144-146658401e2a> in <cell line: 18>()
#      21
#      22     # OpenCV görüntüsünü image olarak kaydet
# ---> 23     cv2.imwrite(image_path, frame)
#      24
#      25     image = Image.open("/content/drive/MyDrive/colab/firedino/frame.jpg").convert("RGB") # load image
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:787: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %%
box_label = ["fire" for i in range(len(boxes[select_mask]))]
box_label
# Out:
# ['fire', 'fire', 'fire']

# %%
box_ops.box_xyxy_to_cxcywh(output['boxes'])
# Out:
# tensor([[0.5049, 0.9595, 0.9291, 0.3566],
#         [0.5723, 0.9729, 0.8706, 0.3451],
#         [0.5357, 0.9744, 0.9142, 0.3298],
#         ...,
#         [0.7532, 0.9864, 0.7035, 0.3670],
#         [0.0391, 0.9423, 0.9269, 0.2774],
#         [0.7890, 0.9539, 0.7817, 0.4661]], device='cuda:0')

# %%
lines = ""
for box, label in zip(boxes[select_mask], box_label):
  lines += "1 " + " ".join(str(i) for i in box.detach().cpu().numpy()) + "\n"

print(lines)
# Out:
# 1 0.39797315 0.4482342 0.06059611 0.09476006
# 1 0.24957144 0.20009468 0.035394296 0.03878811
# 1 0.7929312 0.5377207 0.04230261 0.085710526
# 1 0.24636726 0.25060937 0.050816268 0.10533786
# 1 0.8978413 0.24158317 0.036588788 0.045447424
# 1 0.7732572 0.18224356 0.035670638 0.03209892
# 1 0.6634702 0.86834985 0.06790328 0.075737
# 1 0.25476256 0.15725526 0.06830263 0.08799338
# 1 0.772482 0.9733873 0.04945302 0.053090215
# 1 0.98446953 0.5958958 0.030818343 0.076993704

# %%
images = os.listdir("/content/drive/MyDrive/colab/kus/images6")
images_path = "/content/drive/MyDrive/colab/kus/images6"
for img in images:
  name = img.split(".")[0]
  path = os.path.join(images_path, img)
  image = Image.open(path).convert("RGB") # load image
  image, _ = transform(image, None)
  # predict images
  output = model.cuda()(image[None].cuda())
  output = postprocessors['bbox'](output, torch.Tensor([[1.0, 1.0]]).cuda())[0]
  thershold = 0.3 # set a thershold
  scores = output['scores']
  labels = output['labels']
  boxes = box_ops.box_xyxy_to_cxcywh(output['boxes'])
  select_mask = scores > thershold

  box_label = [id2name[int(item)] for item in labels[select_mask]]
  exit_while_loop = False

  while thershold >= 0.0:
    print(thershold)
    select_mask = scores > thershold
    box_label = [id2name[int(item)] for item in labels[select_mask]]
    #print("uzunluk: {}".format(len(boxes[select_mask])))
    if len(boxes[select_mask]) != 0 and "bird" in box_label:
      line = ""
      for box, label in zip(boxes[select_mask], box_label):
        if label == "bird":
          line += "1 " + " ".join(str(i) for i in box.detach().cpu().numpy()) + "\n"
      with open(os.path.join("/content/drive/MyDrive/colab/kus/labels", name+".txt"), "w") as f:
          f.writelines(line)
      break
    else:
      thershold = thershold - 0.02
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# 0.3
# 0.3
# 0.27999999999999997
# 0.3
# 0.3
# 0.3
# 0.27999999999999997
# 0.25999999999999995
# 0.23999999999999996
# 0.21999999999999997
# 0.19999999999999998
# 0.18
# 0.16
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.3
# 0.27999999999999997
# 0.25999999999999995
# 0.23999999999999996
# 0.21999999999999997
# 0.19999999999999998
# 0.18
# 0.3
# 0.27999999999999997
# 0.25999999999999995
# 0.23999999999999996
# 0.21999999999999997
# 0.19999999999999998
# 0.18
# 0.16
# 0.14
# 0.3
# 0.3
# 0.3
# 0.3
# 0.27999999999999997
# 0.25999999999999995
# ...

# %%
box_label = [id2name[int(item)] for item in labels[select_mask]]

# %%
" ".join(str(i) for i in boxes[select_mask][0].detach().cpu().numpy())
# Out:
# '0.3646406 0.49371648 0.023875475 0.029565424'

# %%
# !pip install ultralytics

# %%
# !pip install roboflow

# %%
# optional: upload your model to Roboflow for deployment
from roboflow import Roboflow

rf = Roboflow(api_key="HpErSx7pnJl7J8uivNBz")
project = rf.workspace().project("birds-10uiw")
project.version("9").deploy(model_type="yolovh", model_path=f"/content/drive/MyDrive/colab")
